# %% [markdown]
# # **Image Preprocessing**

# %% [markdown]
# # Import ImageDataGenerator Library And Configure It

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,horizontal_flip=True,vertical_flip=True,zoom_range=0.2)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # **Apply ImageDataGenerator Functionality To Train And Test Set**

# %%
x_train=train_datagen.flow_from_directory(r"/content/drive/MyDrive/dataset",target_size=(64,64),
                                          class_mode="categorical",batch_size=30)
# Out:
# Found 18110 images belonging to 10 classes.

# %%
x_test=test_datagen.flow_from_directory(r"/content/drive/MyDrive/dataset",target_size=(64,64),
                                                            class_mode="categorical",batch_size=30)
# Out:
# Found 18110 images belonging to 10 classes.

# %% [markdown]
# # **Model Building**

# %% [markdown]
# # Import The Required Model Building Libraries

# %%
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten

# %% [markdown]
# # **Initialize The Model**

# %%
model=Sequential()

# %% [markdown]
# # **Add The Convolution Layer**

# %%
model.add(Convolution2D(32,(3,3),activation="relu",input_shape=(64,64,3)))
#No of feature detectors, size of feature detector, image size, activation function

# %% [markdown]
# # **Add The Pooling Layer**

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# # **Add The Flatten Layer**

# %%
model.add(Flatten())

# %% [markdown]
# # **Adding The Dense Layers**

# %%
model.add(Dense(200,activation='relu'))

# %%
model.add(Dense(200,activation='relu'))

# %%
model.add(Dense(9,activation="softmax"))

# %% [markdown]
# # **Compile The Model**

# %%
model.compile(loss="categorical_crossentropy",metrics=["accuracy"],optimizer='adam')

# %%
len(x_train)
# Out:
# 604

# %%
len(x_test)
# Out:
# 604

# %%
model.fit(x_train,epochs=9,validation_data=x_test,steps_per_epoch=len(x_train),validation_steps=len(x_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6f8c8e473db9> in <module>
# ----> 1 model.fit(x_train,epochs=9,validation_data=x_test,steps_per_epoch=len(x_train),validation_steps=len(x_test))
#
# NameError: name 'model' is not defined
